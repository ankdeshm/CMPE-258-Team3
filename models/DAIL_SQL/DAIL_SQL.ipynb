# %%
# !apt install default-jre
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   default-jre-headless fonts-dejavu-core fonts-dejavu-extra libatk-wrapper-java
#   libatk-wrapper-java-jni libfontenc1 libxkbfile1 libxtst6 libxxf86dga1 openjdk-11-jre x11-utils
# Suggested packages:
#   mesa-utils
# The following NEW packages will be installed:
#   default-jre default-jre-headless fonts-dejavu-core fonts-dejavu-extra libatk-wrapper-java
#   libatk-wrapper-java-jni libfontenc1 libxkbfile1 libxtst6 libxxf86dga1 openjdk-11-jre x11-utils
# 0 upgraded, 12 newly installed, 0 to remove and 16 not upgraded.
# Need to get 3,720 kB of archives.
# After this operation, 12.7 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jre-headless amd64 2:1.11-72build2 [3,042 B]
# ...

# %%
# !apt install default-jdk
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   default-jdk-headless libice-dev libsm-dev libxt-dev openjdk-11-jdk
# Suggested packages:
#   libice-doc libsm-doc libxt-doc openjdk-11-demo openjdk-11-source visualvm
# The following NEW packages will be installed:
#   default-jdk default-jdk-headless libice-dev libsm-dev libxt-dev openjdk-11-jdk
# 0 upgraded, 6 newly installed, 0 to remove and 16 not upgraded.
# Need to get 1,794 kB of archives.
# After this operation, 3,126 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jdk-headless amd64 2:1.11-72build2 [942 B]
# Get:2 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 openjdk-11-jdk amd64 11.0.21+9-0ubuntu1~22.04 [1,327 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 default-jdk amd64 2:1.11-72build2 [908 B]
# ...

# %%
# !python -m pip install --upgrade pip
# !pip install openai==0.28
# !pip install cohere
# !pip install tiktoken

# %%
# %cd /content/drive/MyDrive/CMPE258/DAIL_SQL_main/DAIL_SQL_main/
# Out:
# /content/drive/MyDrive/CMPE258/DAIL_SQL_main/DAIL_SQL_main

# %%
# !pip install -r requirements.txt
# !python nltk_downloader.py

# %%
# %cd /content/drive/MyDrive/CMPE258/third_party/stanford-corenlp-full-2018-10-05
# Out:
# /content/drive/MyDrive/CMPE258/third_party/stanford-corenlp-full-2018-10-05

# %%
# !nohup java -mx4g -cp "*" edu.stanford.nlp.pipeline.StanfordCoreNLPServer -port 9003 -timeout 15000 &
# Out:
# nohup: appending output to 'nohup.out'

# %%
# !ps aux | grep java
# Out:
# root        3917 20.0  0.1 7083960 58204 ?       Sl   18:10   0:00 java -mx4g -cp * edu.stanford.nlp
# root        3944  0.0  0.0   7372  3464 ?        S    18:10   0:00 /bin/bash -c ps aux | grep java
# root        3946  0.0  0.0   6480  2376 ?        S    18:10   0:00 grep java

# %%
# !tail -n 50 /content/drive/MyDrive/CMPE258/third_party/stanford-corenlp-full-2018-10-05/nohup.out
# Out:
# give me a restaurant in the bay area ?
# [pool-1-thread-2] INFO CoreNLP - [/127.0.0.1:54498] API call w/annotators tokenize,ssplit,pos,lemma
# where can i find a restaurant in the bay area ?
# [pool-1-thread-2] INFO CoreNLP - [/127.0.0.1:54514] API call w/annotators tokenize,ssplit,pos,lemma
# give me a good restaurant in the bay area ?
# [pool-1-thread-2] INFO CoreNLP - [/127.0.0.1:54530] API call w/annotators tokenize,ssplit,pos,lemma
# what are some good restaurants in the bay area ?
# [pool-1-thread-2] INFO CoreNLP - [/127.0.0.1:54552] API call w/annotators tokenize,ssplit,pos,lemma
# give me some good restaurants in the bay area ?
# [pool-1-thread-2] INFO CoreNLP - [/127.0.0.1:54570] API call w/annotators tokenize,ssplit,pos,lemma
# what is a good restaurant in the bay area ?
# [main] INFO CoreNLP - --- StanfordCoreNLPServer#main() called ---
# [main] INFO CoreNLP - setting default constituency parser
# ...

# %%
# !cat /content/drive/MyDrive/CMPE258/third_party/stanford-corenlp-full-2018-10-05/nohup.out

# %%
# %cd /content/drive/MyDrive/CMPE258/DAIL_SQL_main/DAIL_SQL_main
# Out:
# /content/drive/MyDrive/CMPE258/DAIL_SQL_main/DAIL_SQL_main

# %%
# !python data_preprocess.py
# Out:
# spider_dir: /content/drive/MyDrive/CMPE258/dataset/spider
# DB connections: 100% 166/166 [02:45<00:00,  1.00it/s]
# test section linking: 100% 1034/1034 [06:30<00:00,  2.65it/s]
# train section linking: 100% 8659/8659 [53:07<00:00,  2.72it/s]

# %% [markdown]
# # Prompt Generation
# #### Select examples with masked question similarity:

# %%
# !python generate_question.py \
--data_type spider \
--split test \
--tokenizer gpt-3.5-turbo \
--max_seq_len 4096 \
--prompt_repr SQL \
--k_shot 1 \
--example_type QA \
--selector_type  EUCDISQUESTIONMASK
# Out:
# Streaming output truncated to the last 5000 lines.
# sql: SELECT state_name FROM state WHERE state_name NOT IN ( SELECT state_name FROM border_info );
# normalized sql: select state_name from state where state_name not in ( select state_name from border_info )
# sql: SELECT state_name FROM state WHERE state_name NOT IN ( SELECT state_name FROM border_info );
# normalized sql: select state_name from state where state_name not in ( select state_name from border_info )
# sql: SELECT state_name FROM state WHERE state_name NOT IN ( SELECT state_name FROM border_info );
# normalized sql: select state_name from state where state_name not in ( select state_name from border_info )
# sql: SELECT area FROM state WHERE density  =  ( SELECT MIN ( density ) FROM state );
# normalized sql: select area from state where density = ( select min ( density ) from state )
# ...

# %% [markdown]
# #### Select examples considering both question similarity and query similarity:

# %%
# !python generate_question.py \
--data_type spider \
--split test \
--tokenizer gpt-3.5-turbo \
--max_seq_len 4096 \
--selector_type EUCDISMASKPRESKLSIMTHR \
--pre_test_result "/content/drive/MyDrive/CMPE258/DAIL_SQL_main/DAIL_SQL_main/dataset/process/SPIDER-TEST_SQL_1-SHOT_EUCDISQUESTIONMASK_QA-EXAMPLE_CTX-200_ANS-4096/questions_1_shot.json" \
--prompt_repr SQL \
--k_shot 1 \
--example_type QA
# Out:
# Streaming output truncated to the last 5000 lines.
# ...

# %%
# os.environ["OPENAI_API_KEY"] = "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"
# OPENAI_API_KEY = "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"

# %%
# !python ask_llm.py \
--openai_api_key "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"  \
--model gpt-3.5-turbo \
--question "/content/drive/MyDrive/CMPE258/DAIL_SQL_main/DAIL_SQL_main/dataset/process/SPIDER-TEST_SQL_1-SHOT_EUCDISMASKPRESKLSIMTHR_QA-EXAMPLE_CTX-200_ANS-4096"
# Out:
#   0% 0/10 [00:00<?, ?it/s]
# 100% 1/1 [00:00<00:00, 42.37it/s]
# save chosen sqls and results...
#  10% 1/10 [00:01<00:16,  1.80s/it]
# 100% 1/1 [00:00<00:00, 56.04it/s]
# save chosen sqls and results...
#  20% 2/10 [00:02<00:10,  1.27s/it]
# 100% 1/1 [00:00<00:00, 47.29it/s]
# save chosen sqls and results...
#  30% 3/10 [00:08<00:22,  3.25s/it]Repeat for the 1 times for RateLimitError
# Repeat for the 2 times for RateLimitError
#
# 100% 1/1 [00:00<00:00, 48.71it/s]
# save chosen sqls and results...
#  40% 4/10 [00:31<01:06, 11.09s/it]Repeat for the 1 times for RateLimitError
#
# 100% 1/1 [00:00<00:00, 41.15it/s]
# save chosen sqls and results...
#  50% 5/10 [00:44<00:58, 11.74s/it]Repeat for the 1 times for RateLimitError
# Repeat for the 2 times for RateLimitError
#
# 100% 1/1 [00:00<00:00, 39.72it/s]
# save chosen sqls and results...
#  60% 6/10 [01:10<01:07, 16.79s/it]Repeat for the 1 times for RateLimitError
#
# 100% 1/1 [00:00<00:00, 44.03it/s]
# ...

# %% [markdown]
# ## With self-consistency voting:

# %%
# !python ask_llm.py \
--openai_api_key "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" \
--model gpt-3.5-turbo \
--question "/content/drive/MyDrive/CMPE258/DAIL_SQL_main/DAIL_SQL_main/dataset/process/SPIDER-TEST_SQL_1-SHOT_EUCDISQUESTIONMASK_QA-EXAMPLE_CTX-200_ANS-4096" \
--n 5 \
--db_dir "/content/drive/MyDrive/CMPE258/dataset/spider/database" \
--temperature 1.0
# Out:
#   0% 0/10 [00:00<?, ?it/s]
# 100% 1/1 [00:00<00:00, 39.63it/s]
# save chosen sqls and results...
#  10% 1/10 [00:01<00:12,  1.37s/it]
# 100% 1/1 [00:00<00:00, 51.48it/s]
# save chosen sqls and results...
#  20% 2/10 [00:02<00:10,  1.30s/it]
# 100% 1/1 [00:00<00:00, 52.23it/s]
# save chosen sqls and results...
#  30% 3/10 [00:04<00:10,  1.51s/it]Repeat for the 1 times for RateLimitError
# Repeat for the 2 times for RateLimitError
#
# 100% 1/1 [00:00<00:00, 41.59it/s]
# save chosen sqls and results...
#  40% 4/10 [00:25<00:56,  9.44s/it]Repeat for the 1 times for RateLimitError
# Repeat for the 2 times for RateLimitError
#
# 100% 1/1 [00:00<00:00, 35.34it/s]
# save chosen sqls and results...
#  50% 5/10 [00:49<01:12, 14.57s/it]Repeat for the 1 times for RateLimitError
# Repeat for the 2 times for RateLimitError
#
# 100% 1/1 [00:00<00:00, 43.35it/s]
# save chosen sqls and results...
#  60% 6/10 [01:12<01:09, 17.41s/it]Repeat for the 1 times for RateLimitError
#
# ...
